# %%
import numpy as np, matplotlib.pyplot as plt
from volfit.calibrate import calibrate_slice
k = np.linspace(-2,2,41)
iv = 0.25 + 0.05*(k**2)
p, loss = calibrate_slice(k, iv, ttm=0.5)
print(p, "loss:", loss)
plt.plot(k, iv, label="iv"); plt.legend(); plt.savefig("svi_slice.png", dpi=160)
# Out:
# SVIParams(a=np.float64(1e-06), b=np.float64(0.04262215459852011), rho=np.float64(-0.02026619872017895), m=np.float64(-0.033678472047525464), sigma=np.float64(0.6268279294127392)) loss: 2.2946524787575887e-05
